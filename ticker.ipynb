# %%
import yfinance as yf
import pandas as pd
import tqdm

# %%
nasdaq_url = "https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nasdaq&render=download"
nyse_url = "https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nyse&render=download"
amex_url = "https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=amex&render=download"

# Read CSV files
nasdaq_tickers = pd.read_csv(nasdaq_url)
nyse_tickers = pd.read_csv(nyse_url)
amex_tickers = pd.read_csv(amex_url)

# Combine ticker symbols
all_tickers = nasdaq_tickers.append(nyse_tickers).append(amex_tickers)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7f/zzvg3mdj425g3y3pzll4q80h0000gn/T/ipykernel_49769/2999189027.py in <module>
#       4
#       5 # Read CSV files
# ----> 6 nasdaq_tickers = pd.read_csv(nasdaq_url)
#       7 nyse_tickers = pd.read_csv(nyse_url)
#       8 amex_tickers = pd.read_csv(amex_url)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
